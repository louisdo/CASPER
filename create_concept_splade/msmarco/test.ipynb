# %%
with open("/scratch/lamdo/msmarco_splade/data/msmarco/full_collection/raw.tsv") as f:
    for line in f:
        break

# %%
line.split("\t")
# Out:
# ['0',
#  'The presence of communication amid scientific minds was equally important to the success of the Manhattan Project as scientific intellect was. The only cloud hanging over the impressive achievement of the atomic researchers and engineers is what their success truly meant; hundreds of thousands of innocent lives obliterated.\n']

# %%
import json

with open("/scratch/lamdo/msmarco_phrase_vocab/0.json") as f:
    test = json.load(f)

# %%
test
# Out:
# {'manhattan project': [0, 1, 2, 3, 5, 6, 7, 9],
#  'scientific intellect': [0],
#  'communication': [0],
#  'presence': [0],
#  'scientific minds': [0],
#  'atomic bomb': [1, 2],
#  'legacy': [1, 424, 746],
#  'atomic energy': [1],
#  'peaceful uses': [1],
#  'essay': [2],
#  'project': [2, 3, 7],
#  'success': [2, 700, 703, 725],
#  'first atomic bomb': [3, 5],
#  'name': [3, 615],
#  'engineers': [3],
#  'heritage resources': [4],
#  'national nuclear security': [4],
#  'office': [4, 329, 629, 631],
#  'complementary websites': [4],
#  'volume': [4],
#  'gadget': [5],
#  'nuclear age': [5],
#  'atomic scientists': [5],
#  'rich literature': [6],
#  'atomic bombs': [6, 8],
#  'end': [6],
#  'development': [6],
#  'first nuclear weapons': [7],
#  'los alamos laboratory': [7],
#  'development undertaking': [7],
#  'corps': [8],
#  'manhattan project-': [8],
#  'secret name': [8],
#  'june 1942': [8],
#  'b reactor': [9],
#  'main reasons hanford': [9],
#  'columbia river': [9],
# ...
