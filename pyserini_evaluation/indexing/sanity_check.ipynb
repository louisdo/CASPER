# %%
import json

# %%
with open("/scratch/lamdo/beir_splade/collections/scifact__splade_maxsim/chunk0.jsonl") as f:
    data = []
    for line in f:
        jline = json.loads(line)
        data.append(jline)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/lamdo/splade/pyserini_evaluation/indexing/sanity_check.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bosprey2.csl.illinois.edu/home/lamdo/splade/pyserini_evaluation/indexing/sanity_check.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> with open("/scratch/lamdo/beir_splade/collections/scifact__splade_maxsim/chunk0.jsonl") as f:
#       <a href='vscode-notebook-cell://ssh-remote%2Bosprey2.csl.illinois.edu/home/lamdo/splade/pyserini_evaluation/indexing/sanity_check.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     data = []
#       <a href='vscode-notebook-cell://ssh-remote%2Bosprey2.csl.illinois.edu/home/lamdo/splade/pyserini_evaluation/indexing/sanity_check.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     for line in f:
#
# ...

# %%
len(data)
# Out:
# 2000

# %%
data[0]
# Out:
# {'_id': '4983',
#  'title': 'Microstructural development of human newborn cerebral white matter assessed in vivo by diffusion tensor magnetic resonance imaging.',
# ...
